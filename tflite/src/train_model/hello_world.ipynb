# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math
import keras
from keras import layers

# %%
print("Numpy " + np.__version__)
print("../tensorflow " + tf.__version__)
print("Keras " + keras.__version__)
# Out:
# Numpy 1.26.4
# ../tensorflow 2.15.0
# Keras 2.15.0

# %%
nsamples = 1000
val_ratio = 0.2
test_ratio = 0.2
tflite_model_name = "sine_model"
c_model_name = "sine_model"

# %%
np.random.seed(1234)
x_values = np.random.uniform(low=0, high=(2 * math.pi), size=nsamples)
plt.plot(x_values)

# %%
y_values = np.sin(x_values) + (0.1 * np.random.randn(x_values.shape[0]))
plt.plot(x_values, y_values, ".")

# %%
val_split = int(val_ratio * nsamples)
test_split = int(val_split + (test_ratio * nsamples))
x_val, x_test, x_train = np.split(x_values, [val_split, test_split])
y_val, y_test, y_train = np.split(y_values, [val_split, test_split])

assert (x_train.size + x_val.size + x_test.size) == nsamples

plt.plot(x_train, y_train, "b.", label="Train")
plt.plot(x_test, y_test, "r.", label="Test")
plt.plot(x_val, y_val, "y.", label="Validation")
plt.legend()
plt.show()

# %%
print(x_values.shape, y_values.shape)
print(x_train.shape)
# (357, )
# (2, )
# (1, 357)
# Out:
# (1000,) (1000,)
# (600,)

# %%
model = keras.Sequential()
model.add(layers.Dense(16, activation="relu", input_shape=(1,)))
model.add(layers.Dense(16, activation="relu"))
model.add(layers.Dense(1))

for layer in model.layers:
  print('input shape: ',layer.input_shape, 'output shape: ',layer.output_shape)
# Out:
# input shape:  (None, 1) output shape:  (None, 16)
# input shape:  (None, 16) output shape:  (None, 16)
# input shape:  (None, 16) output shape:  (None, 1)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 16)                32
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 321 (1.25 KB)
# Trainable params: 321 (1.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="rmsprop", loss="mae", metrics=["mae"])
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (600,) (600,)
# (200,) (200,)

# %%
history = model.fit(x_train, y_train, epochs=200, batch_size=100, validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 20ms/step - loss: 0.5595 - mae: 0.5595 - val_loss: 0.5177 - val_mae: 0.5177
# Epoch 2/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5382 - mae: 0.5382 - val_loss: 0.5064 - val_mae: 0.5064
# Epoch 3/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5262 - mae: 0.5262 - val_loss: 0.4995 - val_mae: 0.4995
# Epoch 4/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5168 - mae: 0.5168 - val_loss: 0.4960 - val_mae: 0.4960
# Epoch 5/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5120 - mae: 0.5120 - val_loss: 0.4894 - val_mae: 0.4894
# Epoch 6/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5029 - mae: 0.5029 - val_loss: 0.4835 - val_mae: 0.4835
# Epoch 7/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4973 - mae: 0.4973 - val_loss: 0.4760 - val_mae: 0.4760
# Epoch 8/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4894 - mae: 0.4894 - val_loss: 0.4721 - val_mae: 0.4721
# Epoch 9/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4825 - mae: 0.4825 - val_loss: 0.4670 - val_mae: 0.4670
# Epoch 10/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4749 - mae: 0.4749 - val_loss: 0.4568 - val_mae: 0.4568
# Epoch 11/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4697 - mae: 0.4697 - val_loss: 0.4539 - val_mae: 0.4539
# Epoch 12/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4621 - mae: 0.4621 - val_loss: 0.4467 - val_mae: 0.4467
# Epoch 13/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4554 - mae: 0.4554 - val_loss: 0.4403 - val_mae: 0.4403
# Epoch 14/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4468 - mae: 0.4468 - val_loss: 0.4398 - val_mae: 0.4398
# Epoch 15/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4443 - mae: 0.4443 - val_loss: 0.4300 - val_mae: 0.4300
# Epoch 16/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4351 - mae: 0.4351 - val_loss: 0.4237 - val_mae: 0.4237
# Epoch 17/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4297 - mae: 0.4297 - val_loss: 0.4197 - val_mae: 0.4197
# Epoch 18/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4217 - mae: 0.4217 - val_loss: 0.4119 - val_mae: 0.4119
# Epoch 19/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4150 - mae: 0.4150 - val_loss: 0.4097 - val_mae: 0.4097
# Epoch 20/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4090 - mae: 0.4090 - val_loss: 0.3981 - val_mae: 0.3981
# Epoch 21/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4026 - mae: 0.4026 - val_loss: 0.3957 - val_mae: 0.3957
# Epoch 22/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3978 - mae: 0.3978 - val_loss: 0.3894 - val_mae: 0.3894
# Epoch 23/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3900 - mae: 0.3900 - val_loss: 0.3834 - val_mae: 0.3834
# Epoch 24/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3827 - mae: 0.3827 - val_loss: 0.3779 - val_mae: 0.3779
# Epoch 25/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3761 - mae: 0.3761 - val_loss: 0.3698 - val_mae: 0.3698
# Epoch 26/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3693 - mae: 0.3693 - val_loss: 0.3645 - val_mae: 0.3645
# Epoch 27/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3621 - mae: 0.3621 - val_loss: 0.3652 - val_mae: 0.3652
# Epoch 28/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3554 - mae: 0.3554 - val_loss: 0.3565 - val_mae: 0.3565
# Epoch 29/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3500 - mae: 0.3500 - val_loss: 0.3543 - val_mae: 0.3543
# Epoch 30/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3435 - mae: 0.3435 - val_loss: 0.3444 - val_mae: 0.3444
# Epoch 31/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3375 - mae: 0.3375 - val_loss: 0.3373 - val_mae: 0.3373
# Epoch 32/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3325 - mae: 0.3325 - val_loss: 0.3376 - val_mae: 0.3376
# Epoch 33/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3261 - mae: 0.3261 - val_loss: 0.3310 - val_mae: 0.3310
# Epoch 34/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3220 - mae: 0.3220 - val_loss: 0.3236 - val_mae: 0.3236
# Epoch 35/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3178 - mae: 0.3178 - val_loss: 0.3219 - val_mae: 0.3219
# Epoch 36/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3118 - mae: 0.3118 - val_loss: 0.3318 - val_mae: 0.3318
# Epoch 37/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3092 - mae: 0.3092 - val_loss: 0.3160 - val_mae: 0.3160
# Epoch 38/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3053 - mae: 0.3053 - val_loss: 0.3214 - val_mae: 0.3214
# Epoch 39/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3015 - mae: 0.3015 - val_loss: 0.3255 - val_mae: 0.3255
# Epoch 40/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2995 - mae: 0.2995 - val_loss: 0.3127 - val_mae: 0.3127
# Epoch 41/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2962 - mae: 0.2962 - val_loss: 0.3078 - val_mae: 0.3078
# Epoch 42/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2932 - mae: 0.2932 - val_loss: 0.3057 - val_mae: 0.3057
# Epoch 43/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2931 - mae: 0.2931 - val_loss: 0.3116 - val_mae: 0.3116
# Epoch 44/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2882 - mae: 0.2882 - val_loss: 0.3067 - val_mae: 0.3067
# Epoch 45/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2849 - mae: 0.2849 - val_loss: 0.3129 - val_mae: 0.3129
# Epoch 46/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2867 - mae: 0.2867 - val_loss: 0.3073 - val_mae: 0.3073
# Epoch 47/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2840 - mae: 0.2840 - val_loss: 0.3045 - val_mae: 0.3045
# Epoch 48/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2820 - mae: 0.2820 - val_loss: 0.3030 - val_mae: 0.3030
# Epoch 49/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2801 - mae: 0.2801 - val_loss: 0.2991 - val_mae: 0.2991
# Epoch 50/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2785 - mae: 0.2785 - val_loss: 0.2895 - val_mae: 0.2895
# Epoch 51/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2794 - mae: 0.2794 - val_loss: 0.2962 - val_mae: 0.2962
# Epoch 52/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2769 - mae: 0.2769 - val_loss: 0.2976 - val_mae: 0.2976
# Epoch 53/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2758 - mae: 0.2758 - val_loss: 0.2953 - val_mae: 0.2953
# Epoch 54/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2729 - mae: 0.2729 - val_loss: 0.2984 - val_mae: 0.2984
# Epoch 55/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2725 - mae: 0.2725 - val_loss: 0.2940 - val_mae: 0.2940
# Epoch 56/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2709 - mae: 0.2709 - val_loss: 0.2911 - val_mae: 0.2911
# Epoch 57/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2718 - mae: 0.2718 - val_loss: 0.2968 - val_mae: 0.2968
# Epoch 58/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2700 - mae: 0.2700 - val_loss: 0.2916 - val_mae: 0.2916
# Epoch 59/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2710 - mae: 0.2710 - val_loss: 0.2907 - val_mae: 0.2907
# Epoch 60/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2678 - mae: 0.2678 - val_loss: 0.2855 - val_mae: 0.2855
# Epoch 61/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2683 - mae: 0.2683 - val_loss: 0.2962 - val_mae: 0.2962
# Epoch 62/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2684 - mae: 0.2684 - val_loss: 0.2871 - val_mae: 0.2871
# Epoch 63/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2662 - mae: 0.2662 - val_loss: 0.2841 - val_mae: 0.2841
# Epoch 64/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2667 - mae: 0.2667 - val_loss: 0.2815 - val_mae: 0.2815
# Epoch 65/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2653 - mae: 0.2653 - val_loss: 0.2853 - val_mae: 0.2853
# Epoch 66/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2648 - mae: 0.2648 - val_loss: 0.2827 - val_mae: 0.2827
# Epoch 67/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2646 - mae: 0.2646 - val_loss: 0.2782 - val_mae: 0.2782
# Epoch 68/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2634 - mae: 0.2634 - val_loss: 0.2827 - val_mae: 0.2827
# Epoch 69/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2619 - mae: 0.2619 - val_loss: 0.2816 - val_mae: 0.2816
# Epoch 70/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2610 - mae: 0.2610 - val_loss: 0.2793 - val_mae: 0.2793
# Epoch 71/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2602 - mae: 0.2602 - val_loss: 0.2895 - val_mae: 0.2895
# Epoch 72/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2589 - mae: 0.2589 - val_loss: 0.2794 - val_mae: 0.2794
# Epoch 73/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2596 - mae: 0.2596 - val_loss: 0.2757 - val_mae: 0.2757
# Epoch 74/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2601 - mae: 0.2601 - val_loss: 0.2861 - val_mae: 0.2861
# Epoch 75/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2584 - mae: 0.2584 - val_loss: 0.2762 - val_mae: 0.2762
# Epoch 76/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2588 - mae: 0.2588 - val_loss: 0.2727 - val_mae: 0.2727
# Epoch 77/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2571 - mae: 0.2571 - val_loss: 0.2719 - val_mae: 0.2719
# Epoch 78/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2549 - mae: 0.2549 - val_loss: 0.2719 - val_mae: 0.2719
# Epoch 79/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2559 - mae: 0.2559 - val_loss: 0.2665 - val_mae: 0.2665
# Epoch 80/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2569 - mae: 0.2569 - val_loss: 0.2699 - val_mae: 0.2699
# Epoch 81/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2544 - mae: 0.2544 - val_loss: 0.2694 - val_mae: 0.2694
# Epoch 82/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2558 - mae: 0.2558 - val_loss: 0.2683 - val_mae: 0.2683
# Epoch 83/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2521 - mae: 0.2521 - val_loss: 0.2764 - val_mae: 0.2764
# Epoch 84/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2525 - mae: 0.2525 - val_loss: 0.2772 - val_mae: 0.2772
# Epoch 85/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2535 - mae: 0.2535 - val_loss: 0.2651 - val_mae: 0.2651
# Epoch 86/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2516 - mae: 0.2516 - val_loss: 0.2725 - val_mae: 0.2725
# Epoch 87/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2494 - mae: 0.2494 - val_loss: 0.2732 - val_mae: 0.2732
# Epoch 88/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2511 - mae: 0.2511 - val_loss: 0.2718 - val_mae: 0.2718
# Epoch 89/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2488 - mae: 0.2488 - val_loss: 0.2616 - val_mae: 0.2616
# Epoch 90/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2479 - mae: 0.2479 - val_loss: 0.2630 - val_mae: 0.2630
# Epoch 91/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2485 - mae: 0.2485 - val_loss: 0.2639 - val_mae: 0.2639
# Epoch 92/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2487 - mae: 0.2487 - val_loss: 0.2657 - val_mae: 0.2657
# Epoch 93/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2473 - mae: 0.2473 - val_loss: 0.2610 - val_mae: 0.2610
# Epoch 94/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2454 - mae: 0.2454 - val_loss: 0.2586 - val_mae: 0.2586
# Epoch 95/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2466 - mae: 0.2466 - val_loss: 0.2610 - val_mae: 0.2610
# Epoch 96/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2434 - mae: 0.2434 - val_loss: 0.2637 - val_mae: 0.2637
# Epoch 97/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2443 - mae: 0.2443 - val_loss: 0.2548 - val_mae: 0.2548
# Epoch 98/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2439 - mae: 0.2439 - val_loss: 0.2552 - val_mae: 0.2552
# Epoch 99/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2435 - mae: 0.2435 - val_loss: 0.2600 - val_mae: 0.2600
# Epoch 100/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2424 - mae: 0.2424 - val_loss: 0.2541 - val_mae: 0.2541
# Epoch 101/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2416 - mae: 0.2416 - val_loss: 0.2610 - val_mae: 0.2610
# Epoch 102/200
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2401 - mae: 0.2401 - val_loss: 0.2505 - val_mae: 0.2505
# Epoch 103/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2416 - mae: 0.2416 - val_loss: 0.2627 - val_mae: 0.2627
# Epoch 104/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2388 - mae: 0.2388 - val_loss: 0.2556 - val_mae: 0.2556
# Epoch 105/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2387 - mae: 0.2387 - val_loss: 0.2520 - val_mae: 0.2520
# Epoch 106/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2401 - mae: 0.2401 - val_loss: 0.2503 - val_mae: 0.2503
# Epoch 107/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2399 - mae: 0.2399 - val_loss: 0.2525 - val_mae: 0.2525
# Epoch 108/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2363 - mae: 0.2363 - val_loss: 0.2569 - val_mae: 0.2569
# Epoch 109/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2391 - mae: 0.2391 - val_loss: 0.2504 - val_mae: 0.2504
# Epoch 110/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2350 - mae: 0.2350 - val_loss: 0.2549 - val_mae: 0.2549
# Epoch 111/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2395 - mae: 0.2395 - val_loss: 0.2562 - val_mae: 0.2562
# Epoch 112/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2363 - mae: 0.2363 - val_loss: 0.2494 - val_mae: 0.2494
# Epoch 113/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2341 - mae: 0.2341 - val_loss: 0.2468 - val_mae: 0.2468
# Epoch 114/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2337 - mae: 0.2337 - val_loss: 0.2456 - val_mae: 0.2456
# Epoch 115/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2331 - mae: 0.2331 - val_loss: 0.2483 - val_mae: 0.2483
# Epoch 116/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2321 - mae: 0.2321 - val_loss: 0.2416 - val_mae: 0.2416
# Epoch 117/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2325 - mae: 0.2325 - val_loss: 0.2478 - val_mae: 0.2478
# Epoch 118/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2306 - mae: 0.2306 - val_loss: 0.2442 - val_mae: 0.2442
# Epoch 119/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2299 - mae: 0.2299 - val_loss: 0.2401 - val_mae: 0.2401
# Epoch 120/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2319 - mae: 0.2319 - val_loss: 0.2435 - val_mae: 0.2435
# Epoch 121/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2290 - mae: 0.2290 - val_loss: 0.2431 - val_mae: 0.2431
# Epoch 122/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2300 - mae: 0.2300 - val_loss: 0.2388 - val_mae: 0.2388
# Epoch 123/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2283 - mae: 0.2283 - val_loss: 0.2366 - val_mae: 0.2366
# Epoch 124/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2276 - mae: 0.2276 - val_loss: 0.2379 - val_mae: 0.2379
# Epoch 125/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2270 - mae: 0.2270 - val_loss: 0.2366 - val_mae: 0.2366
# Epoch 126/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2307 - mae: 0.2307 - val_loss: 0.2369 - val_mae: 0.2369
# Epoch 127/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2258 - mae: 0.2258 - val_loss: 0.2378 - val_mae: 0.2378
# Epoch 128/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2259 - mae: 0.2259 - val_loss: 0.2418 - val_mae: 0.2418
# Epoch 129/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2246 - mae: 0.2246 - val_loss: 0.2353 - val_mae: 0.2353
# Epoch 130/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2254 - mae: 0.2254 - val_loss: 0.2393 - val_mae: 0.2393
# Epoch 131/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2251 - mae: 0.2251 - val_loss: 0.2328 - val_mae: 0.2328
# Epoch 132/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2243 - mae: 0.2243 - val_loss: 0.2382 - val_mae: 0.2382
# Epoch 133/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2254 - mae: 0.2254 - val_loss: 0.2331 - val_mae: 0.2331
# Epoch 134/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2240 - mae: 0.2240 - val_loss: 0.2389 - val_mae: 0.2389
# Epoch 135/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2209 - mae: 0.2209 - val_loss: 0.2323 - val_mae: 0.2323
# Epoch 136/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2215 - mae: 0.2215 - val_loss: 0.2445 - val_mae: 0.2445
# Epoch 137/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2209 - mae: 0.2209 - val_loss: 0.2416 - val_mae: 0.2416
# Epoch 138/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2228 - mae: 0.2228 - val_loss: 0.2295 - val_mae: 0.2295
# Epoch 139/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2197 - mae: 0.2197 - val_loss: 0.2335 - val_mae: 0.2335
# Epoch 140/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2185 - mae: 0.2185 - val_loss: 0.2315 - val_mae: 0.2315
# Epoch 141/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2185 - mae: 0.2185 - val_loss: 0.2275 - val_mae: 0.2275
# Epoch 142/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2181 - mae: 0.2181 - val_loss: 0.2255 - val_mae: 0.2255
# Epoch 143/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2170 - mae: 0.2170 - val_loss: 0.2253 - val_mae: 0.2253
# Epoch 144/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2184 - mae: 0.2184 - val_loss: 0.2300 - val_mae: 0.2300
# Epoch 145/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2165 - mae: 0.2165 - val_loss: 0.2242 - val_mae: 0.2242
# Epoch 146/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2160 - mae: 0.2160 - val_loss: 0.2245 - val_mae: 0.2245
# Epoch 147/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2160 - mae: 0.2160 - val_loss: 0.2242 - val_mae: 0.2242
# Epoch 148/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2177 - mae: 0.2177 - val_loss: 0.2254 - val_mae: 0.2254
# Epoch 149/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2145 - mae: 0.2145 - val_loss: 0.2270 - val_mae: 0.2270
# Epoch 150/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2144 - mae: 0.2144 - val_loss: 0.2359 - val_mae: 0.2359
# Epoch 151/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2153 - mae: 0.2153 - val_loss: 0.2313 - val_mae: 0.2313
# Epoch 152/200
# 6/6 [==============================] - 0s 10ms/step - loss: 0.2138 - mae: 0.2138 - val_loss: 0.2286 - val_mae: 0.2286
# Epoch 153/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2137 - mae: 0.2137 - val_loss: 0.2254 - val_mae: 0.2254
# Epoch 154/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2130 - mae: 0.2130 - val_loss: 0.2220 - val_mae: 0.2220
# Epoch 155/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2113 - mae: 0.2113 - val_loss: 0.2189 - val_mae: 0.2189
# Epoch 156/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2144 - mae: 0.2144 - val_loss: 0.2182 - val_mae: 0.2182
# Epoch 157/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2107 - mae: 0.2107 - val_loss: 0.2231 - val_mae: 0.2231
# Epoch 158/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2104 - mae: 0.2104 - val_loss: 0.2228 - val_mae: 0.2228
# Epoch 159/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2102 - mae: 0.2102 - val_loss: 0.2187 - val_mae: 0.2187
# Epoch 160/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2091 - mae: 0.2091 - val_loss: 0.2167 - val_mae: 0.2167
# Epoch 161/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2089 - mae: 0.2089 - val_loss: 0.2311 - val_mae: 0.2311
# Epoch 162/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2097 - mae: 0.2097 - val_loss: 0.2223 - val_mae: 0.2223
# Epoch 163/200
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2096 - mae: 0.2096 - val_loss: 0.2206 - val_mae: 0.2206
# Epoch 164/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2093 - mae: 0.2093 - val_loss: 0.2152 - val_mae: 0.2152
# Epoch 165/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2070 - mae: 0.2070 - val_loss: 0.2145 - val_mae: 0.2145
# Epoch 166/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2094 - mae: 0.2094 - val_loss: 0.2210 - val_mae: 0.2210
# Epoch 167/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2047 - mae: 0.2047 - val_loss: 0.2131 - val_mae: 0.2131
# Epoch 168/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2070 - mae: 0.2070 - val_loss: 0.2146 - val_mae: 0.2146
# Epoch 169/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2049 - mae: 0.2049 - val_loss: 0.2170 - val_mae: 0.2170
# Epoch 170/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2046 - mae: 0.2046 - val_loss: 0.2117 - val_mae: 0.2117
# Epoch 171/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2029 - mae: 0.2029 - val_loss: 0.2148 - val_mae: 0.2148
# Epoch 172/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2042 - mae: 0.2042 - val_loss: 0.2115 - val_mae: 0.2115
# Epoch 173/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2019 - mae: 0.2019 - val_loss: 0.2155 - val_mae: 0.2155
# Epoch 174/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2057 - mae: 0.2057 - val_loss: 0.2103 - val_mae: 0.2103
# Epoch 175/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2023 - mae: 0.2023 - val_loss: 0.2101 - val_mae: 0.2101
# Epoch 176/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2025 - mae: 0.2025 - val_loss: 0.2188 - val_mae: 0.2188
# Epoch 177/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2019 - mae: 0.2019 - val_loss: 0.2089 - val_mae: 0.2089
# Epoch 178/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2010 - mae: 0.2010 - val_loss: 0.2153 - val_mae: 0.2153
# Epoch 179/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2005 - mae: 0.2005 - val_loss: 0.2071 - val_mae: 0.2071
# Epoch 180/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2011 - mae: 0.2011 - val_loss: 0.2071 - val_mae: 0.2071
# Epoch 181/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2007 - mae: 0.2007 - val_loss: 0.2086 - val_mae: 0.2086
# Epoch 182/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1992 - mae: 0.1992 - val_loss: 0.2192 - val_mae: 0.2192
# Epoch 183/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1978 - mae: 0.1978 - val_loss: 0.2089 - val_mae: 0.2089
# Epoch 184/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1995 - mae: 0.1995 - val_loss: 0.2154 - val_mae: 0.2154
# Epoch 185/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1969 - mae: 0.1969 - val_loss: 0.2020 - val_mae: 0.2020
# Epoch 186/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1980 - mae: 0.1980 - val_loss: 0.2074 - val_mae: 0.2074
# Epoch 187/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1961 - mae: 0.1961 - val_loss: 0.2087 - val_mae: 0.2087
# Epoch 188/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1959 - mae: 0.1959 - val_loss: 0.2097 - val_mae: 0.2097
# Epoch 189/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1954 - mae: 0.1954 - val_loss: 0.2005 - val_mae: 0.2005
# Epoch 190/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1966 - mae: 0.1966 - val_loss: 0.2095 - val_mae: 0.2095
# Epoch 191/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1948 - mae: 0.1948 - val_loss: 0.2063 - val_mae: 0.2063
# Epoch 192/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1940 - mae: 0.1940 - val_loss: 0.1997 - val_mae: 0.1997
# Epoch 193/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1942 - mae: 0.1942 - val_loss: 0.2023 - val_mae: 0.2023
# Epoch 194/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1932 - mae: 0.1932 - val_loss: 0.1975 - val_mae: 0.1975
# Epoch 195/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1952 - mae: 0.1952 - val_loss: 0.1966 - val_mae: 0.1966
# Epoch 196/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1943 - mae: 0.1943 - val_loss: 0.1984 - val_mae: 0.1984
# Epoch 197/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1919 - mae: 0.1919 - val_loss: 0.1967 - val_mae: 0.1967
# Epoch 198/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1931 - mae: 0.1931 - val_loss: 0.1955 - val_mae: 0.1955
# Epoch 199/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1899 - mae: 0.1899 - val_loss: 0.1986 - val_mae: 0.1986
# Epoch 200/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1891 - mae: 0.1891 - val_loss: 0.1956 - val_mae: 0.1956

# %%
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.legend()
plt.show()

# %%
y = np.sin(1.2)
print(x_test[1])
print(y)
# Out:
# 5.536945502409608
# 0.9320390859672263

# %%
# print(x_test)
predictions = model.predict(x_test)

print(x_test.shape, predictions.shape)

print("predictions =\n", np.round(predictions, decimals=3))
print("actual =\n", y_test)
print(
    len(x_train),
    " ",
    len(x_test),
    " ",
    len(x_val),
    " ",
    len(predictions),
)


# Convert predictions to class labels
# predicted_labels = np.argmax(predictions, axis=1)
# actual_lab`els = np.argmax(outputs_test, axis=1)

# Compare predictions with actual labels
# correct_predictions = np.sum(predicted_labels == actual_labels)
# total_predictions = len(actual_labels)

# Calculate accuracy
# accuracy = correct_predictions / total_predictions
# print("Accuracy:", accuracy)

plt.clf()
plt.title("Comparison")
plt.plot(x_test, y_test, "b.", label="Actual")
plt.plot(x_test, predictions, "r.", label="Prediction")
plt.legend()
plt.show()
# Out:
# 7/7 [==============================] - 0s 838us/step
# (200,) (200, 1)
# predictions =
#  [[-1.068]
#  [-0.935]
#  [-0.588]
#  [-1.002]
#  [-0.721]
#  [-0.71 ]
#  [ 0.233]
#  [ 0.245]
#  [ 0.974]
#  [ 0.787]
#  [ 0.457]
#  [-0.77 ]
#  [-0.116]
#  [-0.634]
#  [-0.592]
#  [ 0.6  ]
#  [ 0.208]
#  [ 0.372]
#  [ 0.034]
#  [-1.074]
#  [ 0.587]
#  [ 0.115]
#  [-0.99 ]
#  [-0.924]
#  [ 0.7  ]
#  [-0.592]
#  [ 0.668]
#  [ 0.967]
#  [ 0.974]
#  [ 0.348]
#  [ 0.401]
#  [-0.62 ]
#  [-0.763]
#  [-1.004]
#  [ 0.572]
#  [ 0.938]
#  [ 0.595]
#  [-0.862]
#  [-0.962]
#  [ 0.308]
#  [ 0.069]
#  [ 0.236]
#  [ 0.759]
#  [-0.548]
#  [ 0.576]
#  [ 0.937]
#  [ 0.326]
#  [-0.58 ]
#  [ 0.157]
#  [-0.899]
#  [ 0.914]
#  [-0.767]
#  [-0.396]
#  [ 0.221]
#  [-0.407]
#  [-0.631]
#  [ 0.927]
#  [-0.82 ]
#  [-0.567]
#  [-0.356]
#  [-0.591]
#  [-0.668]
#  [ 0.984]
#  [-0.807]
#  [-0.901]
#  [-0.725]
#  [-0.677]
#  [ 0.075]
#  [-0.902]
#  [-0.639]
#  [ 0.796]
#  [-0.162]
#  [ 0.477]
#  [ 0.192]
#  [-0.466]
#  [-0.892]
#  [-1.031]
#  [-0.664]
#  [ 0.418]
#  [ 0.398]
#  [ 0.236]
#  [ 0.912]
#  [-0.407]
#  [ 0.91 ]
#  [-0.413]
#  [-0.14 ]
#  [-0.918]
#  [-0.715]
#  [-0.965]
#  [ 0.985]
#  [ 0.995]
#  [-0.687]
#  [-0.963]
#  [-1.075]
#  [-0.606]
#  [ 0.813]
#  [-0.56 ]
#  [-0.854]
#  [-0.589]
#  [ 0.635]
#  [ 0.965]
#  [-1.079]
#  [ 0.285]
#  [-0.452]
#  [-0.209]
#  [ 0.949]
#  [ 0.886]
#  [-0.073]
#  [-1.084]
#  [ 0.481]
#  [-0.706]
#  [ 0.915]
#  [ 0.39 ]
#  [ 0.843]
#  [ 0.864]
#  [ 0.971]
#  [-0.258]
#  [-0.787]
#  [-0.934]
#  [-0.602]
#  [-0.896]
#  [-0.548]
#  [-0.679]
#  [-0.26 ]
#  [-0.946]
#  [ 0.294]
#  [-0.801]
#  [ 0.777]
#  [ 0.328]
#  [ 0.329]
#  [ 0.293]
#  [-0.151]
#  [ 0.424]
#  [-1.097]
#  [ 0.587]
#  [ 0.827]
#  [-1.094]
#  [ 0.444]
#  [-0.938]
#  [-0.426]
#  [-1.033]
#  [-0.94 ]
#  [-0.795]
#  [ 0.195]
#  [-1.046]
#  [-0.17 ]
#  [ 0.964]
#  [-0.926]
#  [ 0.974]
#  [ 0.743]
#  [-0.722]
#  [-1.061]
#  [-0.252]
#  [ 0.218]
#  [ 0.155]
#  [-0.559]
#  [-1.049]
#  [-1.053]
#  [-1.001]
#  [ 0.929]
#  [-0.582]
#  [ 0.383]
#  [ 0.641]
#  [ 0.215]
#  [-0.917]
#  [-0.65 ]
#  [ 0.477]
#  [-0.943]
#  [-0.8  ]
#  [ 0.88 ]
#  [-0.849]
#  [-0.107]
#  [ 0.151]
#  [ 0.276]
#  [ 0.21 ]
#  [ 0.984]
#  [-0.865]
#  [-0.748]
#  [-0.516]
#  [-0.031]
#  [-0.003]
#  [ 0.995]
#  [-0.557]
#  [-0.76 ]
#  [ 0.995]
#  [-0.183]
#  [ 0.533]
#  [-0.706]
#  [-0.939]
#  [-0.415]
#  [-1.09 ]
#  [ 0.919]
#  [ 0.114]
#  [ 0.155]
#  [-1.004]
#  [-0.887]
#  [ 0.07 ]
#  [-0.964]
#  [ 0.975]
#  [ 0.919]]
# actual =
#  [-0.13290638 -0.71766413 -0.62995495 -0.30959555 -0.814318   -1.04871424
#   0.12666701  0.30732904  1.04984587  0.94886897  0.4357331  -1.12967411
#  -0.14009881 -0.83156573 -0.66334366  0.66756184  0.40279929  0.57012728
#   0.22009773 -0.1757798   0.64050599 -0.01846995 -0.42532593 -0.64910055
#   0.87766745 -0.91675927  0.72351629  1.00005363  1.07913582  0.51690686
#   0.51633375 -0.89229507 -1.15758265 -0.57581567  0.70549701  0.78886204
#   0.86014092 -0.96767595 -0.50057705  0.43607174  0.06718084  0.17992977
#   0.86178714 -0.6346059   0.55721644  1.07418756  0.27420392 -0.71873539
#   0.3140195  -0.89769432  0.80017338 -1.02799197 -0.22429274  0.19975744
#  -0.39744965 -0.93273801  0.77169845 -0.86960392 -0.66925501 -0.55358169
#  -0.77938637 -0.91543648  0.82375541 -0.96621704 -0.74108401 -0.99528993
#  -1.00015091  0.26258306 -0.92001382 -0.83462414  0.81709036 -0.05002768
#   0.42550153  0.02167006 -0.51328444 -0.72046318 -0.3499673  -0.84427686
#   0.49725913  0.64264312  0.26390138  0.90469776 -0.26891602  1.01312337
#  -0.53885657 -0.06582557 -0.71735099 -0.81674706 -0.66666653  0.91009437
#   1.07560407 -0.94981667 -0.56061177 -0.09938329 -0.96307869  0.71766684
#  -0.54536491 -0.87516367 -0.71137346  0.59994346  1.0227093  -0.1590448
#   0.38054998 -0.44698575 -0.23106894  0.95114436  0.88565308 -0.02907573
#  -0.1254434   0.71487988 -1.08338977  0.67567961  0.43511079  0.81429796
#   0.78889602  1.04721955 -0.24553429 -1.2424448  -0.89267045 -0.75759382
#  -0.77103041 -0.65655903 -0.97489687 -0.27319795 -0.67366454  0.3540645
#  -0.97614318  0.90163781  0.39480552  0.33785603  0.50492345 -0.14610287
#   0.71924262 -0.14279237  0.63120184  1.06710678  0.0511509   0.6327655
#  -0.50605336 -0.19797521 -0.32624384 -0.65269374 -1.01168467  0.22352528
#  -0.27314993 -0.22272058  0.88399841 -0.77771351  0.90158443  1.03615271
#  -0.98482732 -0.25451876 -0.23030001  0.19879127  0.11055342 -0.53191697
#  -0.12044884 -0.22417895 -0.39671656  1.07358718 -0.45353919  0.39132588
#   0.87596171  0.19193124 -0.54963983 -0.9278761   0.6625307  -0.52791151
#  -0.87235684  0.80290074 -0.90413944 -0.13651103  0.23272745  0.48352668
#   0.20696134  0.91988286 -0.96623558 -0.95622626 -0.55877779  0.04225524
#   0.0055917   1.05956361 -0.56712801 -0.94295594  0.88058266 -0.1831019
#   0.66278929 -1.16486467 -0.62107421 -0.46463123 -0.00510454  0.70247297
#   0.1645337   0.29681806 -0.42869675 -0.81962917  0.23533497 -0.53993951
#   0.90523519  1.03117607]
# 600   200   200   200

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizer = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()

open(tflite_model_name + ".tflite", "wb").write(tflite_model)

import os

basic_model_size = os.path.getsize(tflite_model_name + ".tflite")
print("Model is %d bytes" % basic_model_size)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\quoct\AppData\Local\Temp\tmp3_0nmz3o\assets
# INFO:tensorflow:Assets written to: C:\Users\quoct\AppData\Local\Temp\tmp3_0nmz3o\assets
# Model is 3192 bytes

# %%
interpreter = tf.lite.Interpreter(model_path="sine_model.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(f"input_details: {input_details}")
print(f"output_details: {output_details}")

# input_data = inputs_test[0:1].astype(np.float32)

# print(input_data)
# # push input data to interpreter
# interpreter.set_tensor(input_details[0]["index"], input_data)

# # start execution
# interpreter.invoke()

# # get the output of this model
# output_data = interpreter.get_tensor(output_details[0]["index"])

# print(output_data)
# Out:
# input_details: [{'name': 'serving_default_dense_3_input:0', 'index': 0, 'shape': array([1, 1]), 'shape_signature': array([-1,  1]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# output_details: [{'name': 'StatefulPartitionedCall:0', 'index': 9, 'shape': array([1, 1]), 'shape_signature': array([-1,  1]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
# Function: Convert some hex value into an array for C programming
def hex_to_c_array(hex_data, var_name):
    c_str = ""

    # Create header guard
    c_str += "#ifndef " + var_name.upper() + "_H\n"
    c_str += "#define " + var_name.upper() + "_H\n\n"

    # Add array length at top of file
    c_str += "\nunsigned int " + var_name + "_len = " + str(len(hex_data)) + ";\n"

    # Declare C variable
    c_str += "alignas(8) const unsigned char " + var_name + "[] = {"
    hex_array = []
    for i, val in enumerate(hex_data):
        # Construct string from hex
        hex_str = format(val, "#04x")
        # hex_str = val
        # Add formatting so each line stays within 80 characters
        if (i + 1) < len(hex_data):
            hex_str += ","
        if (i + 1) % 12 == 0:
            hex_str += "\n "
        hex_array.append(hex_str)

    # Add closing brace
    c_str += "\n " + format(" ".join(hex_array)) + "\n};\n\n"

    # Close out header guard
    c_str += "#endif //" + var_name.upper() + "_H"

    return c_str


with open(c_model_name + ".h", "w") as file:
    file.write(hex_to_c_array(tflite_model, c_model_name))
